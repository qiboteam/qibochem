# %% [markdown]
# ## Variational Quantum Deflation Tutorial

# %% [markdown]
# #### H2 example with overlap calculated classically. Work in progress for "swap test" quantum circuit for overlap computation.

# %%
import sys

sys.path.insert(0, '/Users/shijunang/qibochem/src')

# %%
import numpy as np

from qibo import Circuit, gates
from qibo.optimizers import optimize

# %%
# VQD Loss Function

def vqd_loss(params, circuit, hamiltonian, vqd_beta, vqe_gs):
    circuit.set_parameters(params)
    result = hamiltonian.backend.execute_circuit(circuit)
    final_state = result.state()
    overlap = np.inner(vqe_gs, final_state)
    # print(hamiltonian.expectation(final_state), overlap)
    return hamiltonian.expectation(final_state) + vqd_beta * np.abs(overlap) ** 2

# %%
import numpy as np
from qibo.models import VQE

from qibochem.driver import Molecule
from qibochem.ansatz import hf_circuit, ucc_circuit, ucc_ansatz, givens_excitation_ansatz

# Define the H2 molecule and obtain its 1-/2- electron integrals with PySCF
h2 = Molecule([('H', (0.0, 0.0, 0.0)), ('H', (0.0, 0.0, 0.742))])
h2.run_pyscf()
# Generate the molecular Hamiltonian
hamiltonian = h2.hamiltonian()

# Build a UCC circuit ansatz for running VQE
circuit = ucc_ansatz(h2, excitations=[[0,1,2,3]])

# Create and run the VQE, starting with random initial parameters
vqe = VQE(circuit, hamiltonian)

initial_parameters = np.random.uniform(0.0, 2*np.pi, 8)
best, vqe_params, extra = vqe.minimize(initial_parameters)
# Out:
# [Qibo 0.2.16|INFO|2025-09-16 10:34:42]: Using numpy backend on /CPU:0

# %%
results = vqe.circuit()
vqe_gs = results.state()

# %%
givens_circuit = givens_excitation_ansatz(h2, excitations=[[1,2]], include_hf=False, use_mp2_guess=False)
givens_circuit.draw()
# Out:
# 0: ───────────────
# 1: ─o─RY─X─RY─X─o─
# 2: ─X────o────o─X─
# 3: ───────────────

# %%
# Create a concatenated circuit of UCCSD and Given's

vqd_circuit = circuit + givens_circuit 
all_params = np.append(vqe_params, np.random.rand(len(givens_circuit.get_parameters())))
vqd_circuit.set_parameters(all_params)

for count in range(len(circuit.trainable_gates)):
    del vqd_circuit.trainable_gates[0]

# All trainable parameters (Given's trainable, UCCSD not trainable)
vqd_params = all_params[len(vqe_params):]

#nparams has to be manually updated
vqd_circuit.trainable_gates.nparams = len(vqd_circuit.trainable_gates)

vqd_circuit.trainable_gates.set = set(vqd_circuit.trainable_gates)

# %%
best, params, extra = optimize(vqd_loss, vqd_params, args=(vqd_circuit, hamiltonian, 100, vqe_gs), method='BFGS')
# Out:
# [Qibo 0.2.16|ERROR|2025-09-16 10:56:34]: Given list of parameters has length 10 while the circuit contains 2 parametrized gates.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 best, params, extra = optimize(vqd_loss, vqd_params, args=(vqd_circuit, hamiltonian, 100, vqe_gs), method='BFGS')
#
# File ~/anaconda3/envs/qibochem/lib/python3.9/site-packages/qibo/optimizers.py:101, in optimize(loss, initial_parameters, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options, compile, processes, backend)
#      97 from qibo.backends import _check_backend
#      99 backend = _check_backend(backend)
# --> 101 return newtonian(
#     102     loss,
#     103     initial_parameters,
#     104     args,
#     105     method,
#     106     jac,
#     107     hess,
#     108     hessp,
#     109     bounds,
#     110     constraints,
#     111     tol,
#     112     callback,
#     113     options,
#     114     processes,
#     115     backend,
#     116 )
#
# File ~/anaconda3/envs/qibochem/lib/python3.9/site-packages/qibo/optimizers.py:217, in newtonian(loss, initial_parameters, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options, processes, backend)
#     214 else:
#     215     from scipy.optimize import minimize
# --> 217     m = minimize(
#     218         loss,
#     219         backend.to_numpy(initial_parameters),
#     220         args=args,
#     221         method=method,
#     222         jac=jac,
#     223         hess=hess,
#     224         hessp=hessp,
#     225         bounds=bounds,
#     226         constraints=constraints,
#     227         tol=tol,
#     228         callback=callback,
#     229         options=options,
#     230     )
#     231 return m.fun, m.x, m
#
# File ~/anaconda3/envs/qibochem/lib/python3.9/site-packages/scipy/optimize/_minimize.py:708, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     706     res = _minimize_cg(fun, x0, args, jac, callback, **options)
#     707 elif meth == 'bfgs':
# --> 708     res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     709 elif meth == 'newton-cg':
#     710     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     711                              **options)
#
# File ~/anaconda3/envs/qibochem/lib/python3.9/site-packages/scipy/optimize/_optimize.py:1372, in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, xrtol, c1, c2, hess_inv0, **unknown_options)
#    1369 if maxiter is None:
#    1370     maxiter = len(x0) * 200
# -> 1372 sf = _prepare_scalar_function(fun, x0, jac, args=args, epsilon=eps,
#    1373                               finite_diff_rel_step=finite_diff_rel_step)
#    1375 f = sf.fun
#    1376 myfprime = sf.grad
#
# File ~/anaconda3/envs/qibochem/lib/python3.9/site-packages/scipy/optimize/_optimize.py:288, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     284     bounds = (-np.inf, np.inf)
#     286 # ScalarFunction caches. Reuse of fun(x) during grad
#     287 # calculation reduces overall function evaluations.
# --> 288 sf = ScalarFunction(fun, x0, args, grad, hess,
#     289                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     291 return sf
#
# File ~/anaconda3/envs/qibochem/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:166, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     163     self.f = fun_wrapped(self.x)
#     165 self._update_fun_impl = update_fun
# --> 166 self._update_fun()
#     168 # Gradient evaluation
#     169 if callable(grad):
#
# File ~/anaconda3/envs/qibochem/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:262, in ScalarFunction._update_fun(self)
#     260 def _update_fun(self):
#     261     if not self.f_updated:
# --> 262         self._update_fun_impl()
#     263         self.f_updated = True
#
# File ~/anaconda3/envs/qibochem/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:163, in ScalarFunction.__init__.<locals>.update_fun()
#     162 def update_fun():
# --> 163     self.f = fun_wrapped(self.x)
#
# File ~/anaconda3/envs/qibochem/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:145, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     141 self.nfev += 1
#     142 # Send a copy because the user may overwrite it.
#     143 # Overwriting results in undefined behaviour because
#     144 # fun(self.x) will change self.x, with the two no longer linked.
# --> 145 fx = fun(np.copy(x), *args)
#     146 # Make sure the function returns a true scalar
#     147 if not np.isscalar(fx):
#
# Cell In[3], line 4, in vqd_loss(params, circuit, hamiltonian, vqd_beta, vqe_gs)
#       3 def vqd_loss(params, circuit, hamiltonian, vqd_beta, vqe_gs):
# ----> 4     circuit.set_parameters(params)
#       5     result = hamiltonian.backend.execute_circuit(circuit)
#       6     final_state = result.state()
#
# File ~/anaconda3/envs/qibochem/lib/python3.9/site-packages/qibo/models/circuit.py:829, in Circuit.set_parameters(self, parameters)
#     827     except AttributeError:
#     828         nparams = len(parameters)
# --> 829     self._set_parameters_list(parameters, nparams)
#     830 else:
#     831     raise_error(TypeError, f"Invalid type of parameters {type(parameters)}.")
#
# File ~/anaconda3/envs/qibochem/lib/python3.9/site-packages/qibo/models/circuit.py:758, in Circuit._set_parameters_list(self, parameters, n)
#     756         k += gate.nparams - 1
#     757 else:
# --> 758     raise_error(
#     759         ValueError,
#     760         f"Given list of parameters has length {n} while "
#     761         + f"the circuit contains {len(self.trainable_gates)} parametrized gates.",
#     762     )
#
# File ~/anaconda3/envs/qibochem/lib/python3.9/site-packages/qibo/config.py:46, in raise_error(exception, message)
#      39 """Raise exception with logging error.
#      40
#      41 Args:
#      42     exception (Exception): python exception.
#      43     message (str): the error message.
#      44 """
#      45 log.error(message)
# ---> 46 raise exception(message)
#
# ValueError: Given list of parameters has length 10 while the circuit contains 2 parametrized gates.

# %%
from qibochem.measurement import expectation

vqd_circuit.set_parameters(params)
print(f"Expectation value: {expectation(vqd_circuit, hamiltonian):.8f} (Exact first excited state of H2)")
# Out:
# Expectation value: -0.53320754 (Exact first excited state of H2)
